# %%
from __future__ import print_function
# %matplotlib inline
import numpy as np
from hpgmg.finite_volume.ipython_tools import plot

from hpgmg.finite_volume.simple_hpgmg import SimpleMultigridSolver
from hpgmg.finite_volume.operators.jacobi_smoother import JacobiSmoother

# %%
solver = SimpleMultigridSolver.get_solver([
    "6", 
    "--dimensions", "2", 
    "--smoother", "j",
#     "--use-l1-jacobi", 
    "--number-of-vcycles", "6", 
    "--boundary-condition", "p",
    "--problem-name", "sine",
#     "--problem-name", "sine",
#     "--variable-coefficient",
#     "--log",
])
level = solver.fine_level
# Out:
# WARNING:root:average_value_of_rhs 5.40767209239e-16 should be zero, adjusting it

# %%
plot(level.exact_solution, title="exact solution")
plot(level.right_hand_side, title="right hand side")
if solver.is_variable_coefficient:
    plot(level.beta_face_values[0], title="beta_face_i")
    plot(level.beta_face_values[1], title="beta_face_j")
solver.problem_operator.rebuild_operator(level)
if isinstance(solver.smoother, JacobiSmoother):
    if solver.smoother.use_l1_jacobi:
        print("Using Jacobi smoother with l1_inverse")
        plot(level.l1_inverse, title="l1_inverse")
    else:
        print("Using Jacobi smoother with d_inverse")
        plot(level.d_inverse, title="d_inverse")
else:
    print("Using Chebyshev smoother with d_inverse")
    plot(level.d_inverse, title="d_inverse")
    
# plot(level.valid, title="valid", ghost_size=0)
# Out:
# Using Jacobi smoother with d_inverse

# %%
solver.solve()
plot(level.cell_values, title="solved values")
plot(level.residual, title="residual")
# Out:
# MGSolve....
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# v-cycle= 2  norm=3.350238133368657e+02  rel=3.853228004383161e-02
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# v-cycle= 3  norm=2.063881734784345e+02  rel=2.373743770330024e-02
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# v-cycle= 4  norm=1.414720646720198e+02  rel=1.627120520188250e-02
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# v-cycle= 5  norm=1.025644998925272e+02  rel=1.179630782973814e-02
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# USING D_INV
# v-cycle= 6  norm=7.711170584059619e+01  rel=8.868891481214778e-03
