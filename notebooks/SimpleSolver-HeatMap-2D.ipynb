# %%
from __future__ import print_function
# %matplotlib inline
import numpy as np
from hpgmg.finite_volume.ipython_tools import plot

from hpgmg.finite_volume.simple_hpgmg import SimpleMultigridSolver
from hpgmg.finite_volume.operators.jacobi_smoother import JacobiSmoother

# %%
solver = SimpleMultigridSolver.get_solver([
    "6", 
    "--dimensions", "2", 
    "--smoother", "j",
    "--use-l1-jacobi", 
    "--number-of-vcycles", "10", 
    "--boundary-condition", "d",
    "--problem-name", "p4",
    "--variable-coefficient",
    "--log",
])
level = solver.fine_level

# %%
plot(level.exact_solution, title="exact solution")
plot(level.right_hand_side, title="right hand side")
if solver.is_variable_coefficient:
    plot(level.beta_face_values[0], title="beta_face_i")
    plot(level.beta_face_values[1], title="beta_face_j")
solver.problem_operator.rebuild_operator(level)
if isinstance(solver.smoother, JacobiSmoother):
    if solver.smoother.use_l1_jacobi:
        print("Using Jacobi smoother with l1_inverse")
        plot(level.l1_inverse, title="l1_inverse")
    else:
        print("Using Jacobi smoother with d_inverse")
        plot(level.d_inverse, title="d_inverse")
else:
    print("Using Chebyshev smoother with d_inverse")
    plot(level.d_inverse, title="d_inverse")
    
# plot(level.valid, title="valid", ghost_size=0)
# Out:
# Using Jacobi smoother with l1_inverse

# %%
solver.solve()
plot(level.cell_values, title="solved values")
plot(level.residual, title="residual")
# Out:
# Running v-cycle 0
# Running v-cycle 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-dda203a67d70> in <module>()
# ----> 1 solver.solve()
#       2 plot(level.cell_values, title="solved values")
#       3 plot(level.residual, title="residual")
#
# /Users/chick/Aspire/PyCharmProjects/pygmg/hpgmg/finite_volume/simple_hpgmg.pyc in solve(self)
#     271                 print("Running v-cycle {}".format(cycle))
#     272                 # level.residual.print('residual before v_cycle')
# --> 273                 self.v_cycle(level, level.cell_values, level.residual)
#     274                 # level.cell_values.print('cell values after v_cycle')
#     275
#
# /Users/chick/Aspire/PyCharmProjects/pygmg/hpgmg/finite_volume/simple_hpgmg.pyc in v_cycle(self, level, target_mesh, residual_mesh)
#     225
#     226             coarser_level = level.make_coarser_level()
# --> 227             self.problem_operator.rebuild_operator(coarser_level, level)
#     228             self.restrictor.restrict(coarser_level, coarser_level.residual, level.temp, Restriction.RESTRICT_CELL)
#     229             coarser_level.fill_mesh(coarser_level.cell_values, 0.0)
#
# /Users/chick/Aspire/PyCharmProjects/pygmg/hpgmg/finite_volume/operators/stencil_von_neumann_r1.py in rebuild_operator(self, target_level, source_level)
#     163             for dim in range(self.dimensions):
#     164                 self.restrictor.restrict(target_level, target_level.beta_face_values[dim],
# --> 165                                          source_level.beta_face_values[dim], dim+1)
#     166
#     167         adjust_value = 2.0
#
# /Users/chick/Aspire/PyCharmProjects/pygmg/hpgmg/finite_volume/operators/restriction.pyc in restrict(self, level, target, source, restriction_type)
#      56     def restrict(self, level, target, source, restriction_type):
#      57         assert(isinstance(level, SimpleLevel))
# ---> 58         for target_point in level.interior_points():
#      59             source_point = (target_point * 2) - level.ghost_zone
#      60             assert isinstance(target_point, Coord)
#
# /Users/chick/Aspire/PyCharmProjects/pygmg/hpgmg/finite_volume/simple_level.pyc in interior_points(self)
#      83     def interior_points(self):
#      84         for point in self.space.interior_points(self.ghost_zone):
# ---> 85             yield point
#      86
#      87     def valid_indices(self):
#
# KeyboardInterrupt:
