# %%
from __future__ import print_function
# %matplotlib inline
import numpy as np
from hpgmg.finite_volume.ipython_tools import plot

from hpgmg.finite_volume.simple_hpgmg import SimpleMultigridSolver
from hpgmg.finite_volume.operators.jacobi_smoother import JacobiSmoother

# %%
solver = SimpleMultigridSolver.get_solver([
    "5", 
    "--dimensions", "2", 
    "--smoother", "j",
#     "--use-l1-jacobi", 
    "--number-of-vcycles", "16", 
    "--boundary-condition", "p",
    "--problem-name", "sine",
    "--bottom-solver", "smoother",
#     "--problem-name", "p4",
#     "--variable-coefficient",
#     "--log",
])
level = solver.fine_level
# Out:
# Creating Helmholtz (a=1.0, b=1.0) test problem
# Using Jacobi smoother (d_inverse)
# Using smoothing bottom solver
# attempting to create a 64^2 level (with periodic BC) as level 0...
# average_value_of_rhs 5.40767209239e-16 should be zero, adjusting it
# attempting to create a 32^2 level (with periodic BC) as level 1...
# attempting to create a 16^2 level (with periodic BC) as level 2...
# attempting to create a 8^2 level (with periodic BC) as level 3...
# attempting to create a 4^2 level (with periodic BC) as level 4...
# attempting to create a 2^2 level (with periodic BC) as level 5...
# attempting to create a 1^2 level (with periodic BC) as level 6...

# %%
plot(level.exact_solution, title="exact solution")
plot(level.right_hand_side, title="right hand side")
if solver.is_variable_coefficient:
    plot(level.beta_face_values[0], title="beta_face_i")
    plot(level.beta_face_values[1], title="beta_face_j")
solver.problem_operator.rebuild_operator(level)
if isinstance(solver.smoother, JacobiSmoother):
    if solver.smoother.use_l1_jacobi:
        print("Using Jacobi smoother with l1_inverse")
        plot(level.l1_inverse, title="l1_inverse")
    else:
        print("Using Jacobi smoother with d_inverse")
        plot(level.d_inverse, title="d_inverse")
else:
    print("Using Chebyshev smoother with d_inverse")
    plot(level.d_inverse, title="d_inverse")
    
# plot(level.valid, title="valid", ghost_size=0)
# Out:
# Using Jacobi smoother with d_inverse

# %%
solver.solve()
plot(level.cell_values, title="solved values")
plot(level.residual, title="residual")
# Out:
# MGSolve....
# v-cycle= 1  norm=2.026712355492236e+02  rel=2.330993945543724e-02
# v-cycle= 2  norm=7.012043418659596e+01  rel=8.064800468843761e-03
# v-cycle= 3  norm=3.365097646461618e+01  rel=3.870318458763406e-03
# v-cycle= 4  norm=1.898103373185950e+01  rel=2.183076181937016e-03
# v-cycle= 5  norm=1.211242543259505e+01  rel=1.393093118158426e-03
# v-cycle= 6  norm=8.472158899911847e+00  rel=9.744131202369107e-04
# v-cycle= 7  norm=6.324008497176692e+00  rel=7.273467040617940e-04
# v-cycle= 8  norm=4.933310630842243e+00  rel=5.673975974349266e-04
# v-cycle= 9  norm=3.961412261244732e+00  rel=4.556161100878784e-04
# v-cycle=10  norm=3.240609816480173e+00  rel=3.727140578984731e-04
# v-cycle=11  norm=2.682299888241687e+00  rel=3.085008478228488e-04
# v-cycle=12  norm=2.236608057816738e+00  rel=2.572402456222701e-04
# v-cycle=13  norm=1.873573550687070e+00  rel=2.154863560853812e-04
# v-cycle=14  norm=1.573964278888525e+00  rel=1.810272283902943e-04
# v-cycle=15  norm=1.324619366363549e+00  rel=1.523491833844117e-04
# v-cycle=16  norm=1.116005468416006e+00  rel=1.283557571957262e-04
