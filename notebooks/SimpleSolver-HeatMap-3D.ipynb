# %%
from __future__ import print_function
# %matplotlib inline
import numpy as np
from hpgmg.finite_volume.ipython_tools import plot

from math import sin

from hpgmg.finite_volume.simple_hpgmg import SimpleMultigridSolver

# %%
size=4
solver = SimpleMultigridSolver.get_solver([
    "{}".format(size), 
    "--dimensions", "3", 
    "--bottom-solver", "smoother",
    "--smoother", "j",
    "--equation", "h",
    "--boundary-condition", "p",
    "--number-of-vcycles", "10", 
    "--problem", "p6",
    "--log"
])
level = solver.fine_level
# Out:
# Creating Helmholtz (a=1.0, b=1.0) test problem
# Boundary condition is periodic
# Using Jacobi smoother (d_inverse)
# Using smoothing bottom solver
# attempting to create a 16^3 level (with periodic BC) as level 0...
# average_value_of_rhs -1.65171424715e-20 should be zero, adjusting it
# attempting to create a 8^3 level (with periodic BC) as level 1...
# attempting to create a 4^3 level (with periodic BC) as level 2...
# attempting to create a 2^3 level (with periodic BC) as level 3...
# attempting to create a 1^3 level (with periodic BC) as level 4...

# %%
plane_index = size / 2
plot(level.exact_solution[plane_index], title="exact solution")
plot(level.right_hand_side[plane_index], title="right hand side")
solver.solve()
plot(level.cell_values[plane_index], title="solved values")
solver.show_error_information()
# Out:
# MGSolve....
#       v-cycle= 1  norm=8.477906110883112e-04  rel=6.624274367398289e-02
#       v-cycle= 2  norm=4.526393253193907e-05  rel=3.536730698799119e-03
#       v-cycle= 3  norm=2.463365745015295e-06  rel=1.924768964035156e-04
#       v-cycle= 4  norm=1.340280669712146e-07  rel=1.047238170530854e-05
#       v-cycle= 5  norm=7.301865308576017e-09  rel=5.705366226656222e-07
#       v-cycle= 6  norm=3.982461149049099e-10  rel=3.111725343943150e-08
#       v-cycle= 7  norm=2.174029532786559e-11  rel=1.698693984062622e-09
#       v-cycle= 8  norm=1.187688836168377e-12  rel=9.280094177706987e-11
# calculating error... h =  6.250000000000000e-02  ||error|| =  1.455013833851916e-06

# %%
solver.show_timing_information()
# Out:
#                                       0            1            2            3            4
# box dimension                      16^3          8^3          4^3          2^3          1^3
# -------------------------- ------------ ------------ ------------ ------------ ------------
# apply_boundary                 3.135350     0.802387     0.261307     0.101548     0.322354
# blas1                          0.485764     0.065183     0.006685     0.000910     0.000131
# residual                       3.906842     0.234452     0.028292     0.003451     0.007186
# smooth                        24.114187     2.862755     0.363730     0.046556     0.039515
# total cycles                  30.500505     4.089746     0.681181     0.157500     0.381077
#
# timer mg-solve time                        1 events,     38.11061 secs/event,     38.11061 secs total
